# %%
import tensorflow as tf
import os
import cv2
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
train = pd.read_csv("./data/train.csv")
test = pd.read_csv("./data/test.csv")

# %%
train
# Out:
#        product_type  air_temp [K]  process_temp [K]  torque [Nm]  \
# 0               0.0     -1.588786         -1.334958     0.509232
# 1               1.0     -1.485697         -1.108159     0.692203
# 2               0.0     -1.207357         -1.478597     1.317821
# 3               0.0      0.452378          0.675995     0.240406
# 4               0.0     -1.073341         -0.654560    -0.131164
# ...             ...           ...               ...          ...
# 11611           0.0      0.864735          0.751594     0.849135
# 11612           0.0      0.472996          0.328236    -0.074866
# 11613           0.0      0.163729          1.386632    -0.539329
# 11614           0.0      0.730719          0.456755     1.384676
# 11615           0.0      0.668866          0.381156     0.934287
#
#        tool_wear [min]  target
# 0            -1.090530       0
# 1             0.307820       0
# 2            -1.518596       1
# 3             1.221028       1
# 4             0.578929       0
# ...                ...     ...
# 11611         1.178222       1
# 11612         1.206760       0
# 11613         0.550391       0
# 11614        -1.033455       1
# 11615         0.892844       1
#
# [11616 rows x 6 columns]

# %%
test
# Out:
#       product_type  air_temp [K]  process_temp [K]  torque [Nm]  \
# 0              0.0     -0.970252         -0.276562     0.051806
# 1              0.0     -0.599131         -0.669680    -0.219835
# 2              2.0      1.658521          2.067030     0.340336
# 3              1.0      0.936897         -0.049763    -0.504143
# 4              0.0      1.658521          1.613431     0.086993
# ...            ...           ...               ...          ...
# 2900           0.0     -0.325945          0.063637     1.305858
# 2901           2.0     -0.609440         -1.032559     0.030694
# 2902           0.0     -0.836236         -0.397521    -1.215616
# 2903           0.0     -0.037295          0.184596    -2.435185
# 2904           2.0      1.091531          0.214836     0.693610
#
#       tool_wear [min]  target
# 0            0.265013       0
# 1            1.178222       1
# 2           -1.761167       0
# 3           -1.347370       0
# 4           -0.391355       0
# ...               ...     ...
# 2900        -0.519775       1
# 2901         0.935651       0
# 2902         0.479047       1
# 2903         0.093787       1
# 2904        -1.532865       1
#
# [2905 rows x 6 columns]

# %%
X_train = train.drop('target', axis=1)
y_train = train['target']

X_test = test.drop(columns=['target'])
y_test = test['target']

# %%
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train,
                    epochs=50,
                    batch_size=32,
                    validation_data=(X_train, y_train),
                    callbacks=[early_stop])
# Out:
# Epoch 1/50
# c:\Users\Gonza Gaitan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7852 - loss: 0.4659 - val_accuracy: 0.8604 - val_loss: 0.3305
# Epoch 2/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8608 - loss: 0.3381 - val_accuracy: 0.8952 - val_loss: 0.2662
# Epoch 3/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8789 - loss: 0.2949 - val_accuracy: 0.9100 - val_loss: 0.2397
# Epoch 4/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8885 - loss: 0.2745 - val_accuracy: 0.9162 - val_loss: 0.2263
# Epoch 5/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8989 - loss: 0.2587 - val_accuracy: 0.9192 - val_loss: 0.2172
# Epoch 6/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9012 - loss: 0.2528 - val_accuracy: 0.9195 - val_loss: 0.2112
# Epoch 7/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9032 - loss: 0.2463 - val_accuracy: 0.9237 - val_loss: 0.2057
# Epoch 8/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9035 - loss: 0.2434 - val_accuracy: 0.9243 - val_loss: 0.2039
# Epoch 9/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9081 - loss: 0.2357 - val_accuracy: 0.9261 - val_loss: 0.2001
# Epoch 10/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9121 - loss: 0.2310 - val_accuracy: 0.9268 - val_loss: 0.1943
# Epoch 11/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9109 - loss: 0.2277 - val_accuracy: 0.9260 - val_loss: 0.1947
# Epoch 12/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9128 - loss: 0.2241 - val_accuracy: 0.9287 - val_loss: 0.1889
# Epoch 13/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9159 - loss: 0.2203 - val_accuracy: 0.9287 - val_loss: 0.1893
# Epoch 14/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9179 - loss: 0.2138 - val_accuracy: 0.9260 - val_loss: 0.1883
# Epoch 15/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9175 - loss: 0.2154 - val_accuracy: 0.9299 - val_loss: 0.1830
# Epoch 16/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9142 - loss: 0.2154 - val_accuracy: 0.9317 - val_loss: 0.1806
# Epoch 17/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9176 - loss: 0.2117 - val_accuracy: 0.9323 - val_loss: 0.1805
# Epoch 18/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9182 - loss: 0.2093 - val_accuracy: 0.9326 - val_loss: 0.1791
# Epoch 19/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9190 - loss: 0.2076 - val_accuracy: 0.9341 - val_loss: 0.1748
# Epoch 20/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9194 - loss: 0.2067 - val_accuracy: 0.9352 - val_loss: 0.1750
# Epoch 21/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9221 - loss: 0.2004 - val_accuracy: 0.9322 - val_loss: 0.1735
# Epoch 22/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9219 - loss: 0.2011 - val_accuracy: 0.9321 - val_loss: 0.1735
# Epoch 23/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9215 - loss: 0.2018 - val_accuracy: 0.9343 - val_loss: 0.1714
# Epoch 24/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9232 - loss: 0.1972 - val_accuracy: 0.9313 - val_loss: 0.1736
# Epoch 25/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9230 - loss: 0.1979 - val_accuracy: 0.9363 - val_loss: 0.1671
# Epoch 26/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9252 - loss: 0.1977 - val_accuracy: 0.9331 - val_loss: 0.1697
# Epoch 27/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9223 - loss: 0.1975 - val_accuracy: 0.9372 - val_loss: 0.1667
# Epoch 28/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9267 - loss: 0.1966 - val_accuracy: 0.9353 - val_loss: 0.1664
# Epoch 29/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9218 - loss: 0.1940 - val_accuracy: 0.9367 - val_loss: 0.1646
# Epoch 30/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9255 - loss: 0.1975 - val_accuracy: 0.9368 - val_loss: 0.1648
# Epoch 31/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9275 - loss: 0.1955 - val_accuracy: 0.9362 - val_loss: 0.1631
# Epoch 32/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9262 - loss: 0.1898 - val_accuracy: 0.9377 - val_loss: 0.1601
# Epoch 33/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9254 - loss: 0.1911 - val_accuracy: 0.9348 - val_loss: 0.1643
# Epoch 34/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9284 - loss: 0.1892 - val_accuracy: 0.9390 - val_loss: 0.1600
# Epoch 35/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9264 - loss: 0.1904 - val_accuracy: 0.9374 - val_loss: 0.1600
# Epoch 36/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9248 - loss: 0.1870 - val_accuracy: 0.9369 - val_loss: 0.1612
# Epoch 37/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9255 - loss: 0.1884 - val_accuracy: 0.9386 - val_loss: 0.1612
# Epoch 38/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9281 - loss: 0.1816 - val_accuracy: 0.9383 - val_loss: 0.1564
# Epoch 39/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9291 - loss: 0.1846 - val_accuracy: 0.9357 - val_loss: 0.1629
# Epoch 40/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9304 - loss: 0.1825 - val_accuracy: 0.9392 - val_loss: 0.1556
# Epoch 41/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9266 - loss: 0.1916 - val_accuracy: 0.9374 - val_loss: 0.1596
# Epoch 42/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9303 - loss: 0.1825 - val_accuracy: 0.9368 - val_loss: 0.1579
# Epoch 43/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9269 - loss: 0.1841 - val_accuracy: 0.9392 - val_loss: 0.1539
# Epoch 44/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9325 - loss: 0.1817 - val_accuracy: 0.9396 - val_loss: 0.1541
# Epoch 45/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9287 - loss: 0.1789 - val_accuracy: 0.9381 - val_loss: 0.1538
# Epoch 46/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9291 - loss: 0.1803 - val_accuracy: 0.9387 - val_loss: 0.1552
# Epoch 47/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9286 - loss: 0.1804 - val_accuracy: 0.9386 - val_loss: 0.1532
# Epoch 48/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9279 - loss: 0.1831 - val_accuracy: 0.9397 - val_loss: 0.1532
# Epoch 49/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9294 - loss: 0.1801 - val_accuracy: 0.9393 - val_loss: 0.1535
# Epoch 50/50
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9298 - loss: 0.1804 - val_accuracy: 0.9390 - val_loss: 0.1521

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Curva de Loss
ax1.plot(history.history['loss'], label='Train')
ax1.plot(history.history['val_loss'], label='Validación')
ax1.set_title('Curva de Loss')
ax1.set_xlabel('Época')
ax1.set_ylabel('Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Curva de Accuracy
ax2.plot(history.history['accuracy'], label='Train')
ax2.plot(history.history['val_accuracy'], label='Validación')
ax2.set_title('Curva de Accuracy')
ax2.set_xlabel('Época')
ax2.set_ylabel('Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('curvas_aprendizaje.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# Prueba para hacer busqueda de mejores hiperparametros (revisar y  mejorar)

# %%
import keras_tuner as kt

def build_model(hp):
    model = keras.Sequential()
    
    model.add(keras.layers.Dense(
        units=hp.Choice('units_1', [32, 64, 128]),
        activation='relu',
        input_shape=(X_train.shape[1],)
    ))
    
    model.add(keras.layers.Dense(
        units=hp.Choice('units_2', [16, 32, 64]),
        activation='relu'
    ))
    
    model.add(keras.layers.Dense(1, activation='sigmoid'))
    
    model.compile(
        optimizer=keras.optimizers.Adam(
            learning_rate=hp.Choice('lr', [1e-2, 1e-3, 1e-4])
        ),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=20,           # cuántas combinaciones probar
    executions_per_trial=1,
    directory='tuner_results',
    project_name='tp_ia'
)

tuner.search(X_train, y_train,
             epochs=50,
             batch_size=32,
             validation_split=0.2,
             verbose=1)

# Ver los mejores hiperparámetros
tuner.results_summary()
best_hp = tuner.get_best_hyperparameters()[0]
print(f"\nMejor config: units_1={best_hp.get('units_1')}, units_2={best_hp.get('units_2')}, lr={best_hp.get('lr')}")
# Out:
# Trial 2 Complete [00h 00m 00s]
#
# Best val_accuracy So Far: None
# Total elapsed time: 00h 00m 00s
#
# Search: Running Trial #3
#
# Value             |Best Value So Far |Hyperparameter
# 128               |64                |units_1
# 16                |32                |units_2
# 0.001             |0.001             |lr
# Traceback (most recent call last):
#   File "c:\Users\Gonza Gaitan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras_tuner\src\engine\base_tuner.py", line 274, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gonza Gaitan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras_tuner\src\engine\base_tuner.py", line 239, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#   File "c:\Users\Gonza Gaitan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras_tuner\src\engine\tuner.py", line 309, in run_trial
#     self._configure_tensorboard_dir(callbacks, trial, execution)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gonza Gaitan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras_tuner\src\engine\tuner.py", line 421, in _configure_tensorboard_dir
#     from tensorboard.plugins.hparams import api as hparams_api
# ModuleNotFoundError: No module named 'tensorboard'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 37
#      26     return model
#      28 tuner = kt.RandomSearch(
#      29     build_model,
#      30     objective='val_accuracy',
#    (...)
#      34     project_name='tp_ia'
#      35 )
# ---> 37 tuner.search(X_train, y_train,
#      38              epochs=50,
#      39              batch_size=32,
#      40              validation_split=0.2,
#      41              verbose=1)
#      43 # Ver los mejores hiperparámetros
#      44 tuner.results_summary()
#
# File c:\Users\Gonza Gaitan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:235, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     233     self.on_trial_begin(trial)
#     234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
# --> 235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File c:\Users\Gonza Gaitan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:339, in BaseTuner.on_trial_end(self, trial)
#     333 def on_trial_end(self, trial):
#     334     """Called at the end of a trial.
#     335
#     336     Args:
#     337         trial: A `Trial` instance.
#     338     """
# --> 339     self.oracle.end_trial(trial)
#     340     self.save()
#
# File c:\Users\Gonza Gaitan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras_tuner\src\engine\oracle.py:108, in synchronized.<locals>.wrapped_func(*args, **kwargs)
#     106     LOCKS[oracle].acquire()
#     107     THREADS[oracle] = thread_name
# --> 108 ret_val = func(*args, **kwargs)
#     109 if need_acquire:
#     110     THREADS[oracle] = None
#
# File c:\Users\Gonza Gaitan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras_tuner\src\engine\oracle.py:588, in Oracle.end_trial(self, trial)
#     586 if not self._retry(trial):
#     587     self.end_order.append(trial.trial_id)
# --> 588     self._check_consecutive_failures()
#     590 self._save_trial(trial)
#     591 self.save()
#
# File c:\Users\Gonza Gaitan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras_tuner\src\engine\oracle.py:545, in Oracle._check_consecutive_failures(self)
#     543     consecutive_failures = 0
#     544 if consecutive_failures == self.max_consecutive_failed_trials:
# --> 545     raise RuntimeError(
#     546         "Number of consecutive failures exceeded the limit "
#     547         f"of {self.max_consecutive_failed_trials}.\n"
#     548         + (trial.message or "")
#     549     )
#
# RuntimeError: Number of consecutive failures exceeded the limit of 3.
# Traceback (most recent call last):
#   File "c:\Users\Gonza Gaitan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras_tuner\src\engine\base_tuner.py", line 274, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gonza Gaitan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras_tuner\src\engine\base_tuner.py", line 239, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#   File "c:\Users\Gonza Gaitan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras_tuner\src\engine\tuner.py", line 309, in run_trial
#     self._configure_tensorboard_dir(callbacks, trial, execution)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gonza Gaitan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras_tuner\src\engine\tuner.py", line 421, in _configure_tensorboard_dir
#     from tensorboard.plugins.hparams import api as hparams_api
# ModuleNotFoundError: No module named 'tensorboard'
